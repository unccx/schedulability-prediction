# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)
schedulable_ratio = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9871,
    0.9247,
    0.7670,
    0.4208,
    0.1055,
]

pos_ratio = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9412,
    0.7264,
    0.4326,
    0.1346,
    0.0288,
]

precision = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9937,
    0.9190,
    0.7175,
    0.3017,
    0.0541,
]

recall = [
    1.0000,
    0.9974,
    0.9736,
    0.8606,
    0.8376,
    0.7644,
    0.6509,
    0.6261,
    0.6648,
    0.5385,
]
sufficient_ratio = [
    1.0000,
    1,
    0.86442,
    0.44608,
    0.09566,
    0.00346,
    0,
    0,
    0,
    0,
]
plt.plot(
    x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="simulation"
)
plt.plot(
    x,
    [i * 100 for i in pos_ratio],
    "o-",
    color="y",
    label="our method",
)
# plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
# plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.plot(
    x, [i * 100 for i in sufficient_ratio], "*-", color="r", label="sufficient test"
)
plt.xlabel("System utilization (%)")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.savefig("utilization.svg", format="svg")
plt.show()

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)


precision = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9937,
    0.9190,
    0.7175,
    0.3017,
    0.0541,
]

recall = [
    1.0000,
    0.9974,
    0.9736,
    0.8606,
    0.8376,
    0.7644,
    0.6509,
    0.6261,
    0.6648,
    0.5385,
]


plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.xlabel("System utilization (%)")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.show()

# %%
import matplotlib.pyplot as plt

# 折线图

schedulable_ratio = [0.7915, 0.8104, 0.8411, 0.8606, 0.8504, 0.6898]

pos_ratio = [0.3846, 0.4168, 0.4690, 0.5225, 0.6042, 0.6710]

precision = [0.9744, 0.9426, 0.9009, 0.7940, 0.7398, 0.7166]

recall = [0.4302, 0.6378, 0.7372, 0.8860, 0.9505, 0.9820]

# sufficient_ratio = [
#     1.0000,
#     1,
#     0.86442,
#     0.44608,
#     0.09566,
#     0.00346,
#     0,
#     0,
#     0,
#     0,
# ]

x = range(2, 8)
xticks_label = [f"{i}" for i in x]
plt.xticks(x, xticks_label)

plt.plot(
    x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="schedulable"
)
plt.plot(
    x,
    [i * 100 for i in pos_ratio],
    "o-",
    color="y",
    label="pos_ratio",
)
plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
# plt.plot(x, [i * 100 for i in sufficient_ratio], "*-", color="r", label="sufficient")
plt.xlabel("Task set cardinality")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.show()

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)


precision = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9937,
    0.9190,
    0.7175,
    0.3017,
    0.0541,
]

recall = [
    1.0000,
    0.9974,
    0.9736,
    0.8606,
    0.8376,
    0.7644,
    0.6509,
    0.6261,
    0.6648,
    0.5385,
]


plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.xlabel("Task set cardinality")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.show()

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)
schedulable_ratio = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9871,
    0.9247,
    0.7670,
    0.4208,
    0.1055,
]

pos_ratio = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9412,
    0.7264,
    0.4326,
    0.1346,
    0.0288,
]

precision = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9937,
    0.9190,
    0.7175,
    0.3017,
    0.0541,
]

recall = [
    1.0000,
    0.9974,
    0.9736,
    0.8606,
    0.8376,
    0.7644,
    0.6509,
    0.6261,
    0.6648,
    0.5385,
]
sufficient_ratio = [
    1.0000,
    1,
    0.86442,
    0.44608,
    0.09566,
    0.00346,
    0,
    0,
    0,
    0,
]
plt.plot(
    x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="simulation"
)
plt.plot(
    x,
    [i * 100 for i in pos_ratio],
    "o-",
    color="y",
    label="prediction",
)
plt.plot(
    x,
    [i * j * 100 for i, j in zip(pos_ratio, precision)],
    "v--",
    color="y",
    label="prediction (without error)",
)
# plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
# plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.plot(
    x, [i * 100 for i in sufficient_ratio], "*-", color="r", label="sufficient test"
)
plt.xlabel("System utilization (%)")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.savefig("utilization.svg", format="svg")
plt.show()

for k in [i * 100 for i in sufficient_ratio]:
    print(k)
# Out:
# 100.0
# 100
# 86.442
# 44.608
# 9.565999999999999
# 0.346
# 0
# 0
# 0
# 0
