# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)
schedulable_ratio = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9871,
    0.9247,
    0.7670,
    0.4208,
    0.1055,
]

pos_ratio = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9412,
    0.7264,
    0.4326,
    0.1346,
    0.0288,
]

precision = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9937,
    0.9190,
    0.7175,
    0.3017,
    0.0541,
]

recall = [
    1.0000,
    0.9974,
    0.9736,
    0.8606,
    0.8376,
    0.7644,
    0.6509,
    0.6261,
    0.6648,
    0.5385,
]
sufficient_ratio = [
    1.0000,
    1,
    0.86442,
    0.44608,
    0.09566,
    0.00346,
    0,
    0,
    0,
    0,
]
plt.plot(
    x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="simulation"
)
plt.plot(
    x,
    [i * 100 for i in pos_ratio],
    "o-",
    color="y",
    label="our method",
)
# plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
# plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.plot(
    x, [i * 100 for i in sufficient_ratio], "*-", color="r", label="sufficient test"
)
plt.xlabel("System utilization (%)")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.savefig("utilization.svg", format="svg")
plt.show()

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)


precision = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9937,
    0.9190,
    0.7175,
    0.3017,
    0.0541,
]

recall = [
    1.0000,
    0.9974,
    0.9736,
    0.8606,
    0.8376,
    0.7644,
    0.6509,
    0.6261,
    0.6648,
    0.5385,
]


plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.xlabel("System utilization (%)")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.show()

# %%
import matplotlib.pyplot as plt

# 折线图

schedulable_ratio = [0.7915, 0.8104, 0.8411, 0.8606, 0.8504, 0.6898]

pos_ratio = [0.3846, 0.4168, 0.4690, 0.5225, 0.6042, 0.6710]

precision = [0.9744, 0.9426, 0.9009, 0.7940, 0.7398, 0.7166]

recall = [0.4302, 0.6378, 0.7372, 0.8860, 0.9505, 0.9820]

# sufficient_ratio = [
#     1.0000,
#     1,
#     0.86442,
#     0.44608,
#     0.09566,
#     0.00346,
#     0,
#     0,
#     0,
#     0,
# ]

x = range(2, 8)
xticks_label = [f"{i}" for i in x]
plt.xticks(x, xticks_label)

plt.plot(
    x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="schedulable"
)
plt.plot(
    x,
    [i * 100 for i in pos_ratio],
    "o-",
    color="y",
    label="pos_ratio",
)
plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
# plt.plot(x, [i * 100 for i in sufficient_ratio], "*-", color="r", label="sufficient")
plt.xlabel("Task set cardinality")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.show()

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)


precision = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9937,
    0.9190,
    0.7175,
    0.3017,
    0.0541,
]

recall = [
    1.0000,
    0.9974,
    0.9736,
    0.8606,
    0.8376,
    0.7644,
    0.6509,
    0.6261,
    0.6648,
    0.5385,
]


plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.xlabel("Task set cardinality")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.show()

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)
schedulable_ratio = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9871,
    0.9247,
    0.7670,
    0.4208,
    0.1055,
]

pos_ratio = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9412,
    0.7264,
    0.4326,
    0.1346,
    0.0288,
]

precision = [
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    1.0000,
    0.9937,
    0.9190,
    0.7175,
    0.3017,
    0.0541,
]

recall = [
    1.0000,
    0.9974,
    0.9736,
    0.8606,
    0.8376,
    0.7644,
    0.6509,
    0.6261,
    0.6648,
    0.5385,
]
sufficient_ratio = [
    1.0000,
    1,
    0.86442,
    0.44608,
    0.09566,
    0.00346,
    0,
    0,
    0,
    0,
]
plt.plot(
    x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="exact test"
)
plt.plot(
    x,
    [i * 100 for i in pos_ratio],
    "o-",
    color="y",
    label="prediction",
)
plt.plot(
    x,
    [i * j * 100 for i, j in zip(pos_ratio, precision)],
    "v--",
    color="y",
    label="prediction (without error)",
)
# plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
# plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.plot(
    x, [i * 100 for i in sufficient_ratio], "*-", color="r", label="sufficient test"
)
plt.xlabel("System utilization (%)")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.savefig("utilization.svg", format="svg")
plt.show()

for k in [i * 100 for i in sufficient_ratio]:
    print(k)
# Out:
# 100.0
# 100
# 86.442
# 44.608
# 9.565999999999999
# 0.346
# 0
# 0
# 0
# 0

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(10)
xticks_label = [f"{i*10}-{(i+1)*10}" for i in x]
plt.xticks(x, xticks_label)
schedulable_ratio = [
    1.0,
    1.0,
    1.0,
    0.9953874538745388,
    0.9544235924932976,
    0.8488888888888889,
    0.6030195381882771,
    0.35989256938227393,
    0.168141592920354,
    0.06893464637421665,
]

pos_ratio = [
    1.0000,
    1.0000,
    0.9988,
    0.9102,
    0.6591,
    0.4694,
    0.3265,
    0.2519,
    0.1972,
    0.1649,
]

precision = [
    1.0000,
    1.0000,
    0.9988,
    0.9070,
    0.6473,
    0.4360,
    0.2921,
    0.2672,
    0.1500,
    0.2000,
]

recall = [
    1.0000,
    1.0000,
    0.9965,
    0.9488,
    0.7599,
    0.4924,
    0.2409,
    0.0995,
    0.0156,
    0.0109,
]
sufficient_ratio = [
    1.0,
    1.0,
    1.0,
    0.992619926199262,
    0.9472743521000894,
    0.824,
    0.5843694493783304,
    0.3231871083258729,
    0.13982300884955753,
    0.03581020590868397,
]
plt.plot(
    x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="exact test"
)
# plt.plot(
#     x,
#     [i * 100 for i in pos_ratio],
#     "o-",
#     color="y",
#     label="prediction",
# )
# plt.plot(
#     x,
#     [i * j * 100 for i, j in zip(pos_ratio, precision)],
#     "v--",
#     color="y",
#     label="prediction (without error)",
# )
# plt.plot(x, [i * 100 for i in precision], "^-", color="olivedrab", label="precision")
# plt.plot(x, [i * 100 for i in recall], "D-", color="b", label="recall")
plt.plot(
    x, [i * 100 for i in sufficient_ratio], "*-", color="r", label="sufficient test"
)
plt.xlabel("System utilization (%)")  # 横坐标名字
plt.ylabel("Percentage of schedulable task set (%)")  # 纵坐标名字
plt.legend(loc="best")  # 图例
plt.savefig("utilization.svg", format="svg")
plt.show()

for k in [i * 100 for i in sufficient_ratio]:
    print(k)
# Out:
# 100.0
# 100.0
# 100.0
# 99.2619926199262
# 94.72743521000893
# 82.39999999999999
# 58.43694493783303
# 32.318710832587286
# 13.982300884955754
# 3.5810205908683974

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(5, 10)
xticks_label = [f"{i}" for i in x]
plt.xticks(x, xticks_label)

hyper_periods = [
    738682.8751000037,
    5826102.602800028,
    47724365.06190013,
    282389941.7052999,
    1064352324.5514961,
    # 6000901137.228445,
    # 11762845773.520798,
    # 37747344739.15521,
    # 164949375324.62085,
    # 302476919188.39594,
]
# plt.plot(
#     x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="exact test"
# )
plt.plot(x, hyper_periods, "*-", color="r")
plt.xlabel("Taskset Cardinality")  # 横坐标名字
plt.ylabel("Average Hyper Period")  # 纵坐标名字
plt.yscale("log")
plt.legend(loc="best")  # 图例
plt.savefig("hyper_periods.svg", format="svg")
plt.show()
# Out:
# /tmp/ipykernel_4007157/731573984.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="best")  # 图例

# %%
import matplotlib.pyplot as plt

# 折线图
x = range(5, 9)
xticks_label = [f"{i}" for i in x]
plt.xticks(x, xticks_label)

hyper_periods = [
    167395.69785538793,
    1208347.3134063291,
    2922492.630233715,
    5156188.276901583,
]
# plt.plot(
#     x, [i * 100 for i in schedulable_ratio], "s-", color="navy", label="exact test"
# )
plt.plot(x, hyper_periods, "*-", color="r", label="Burmyakov2022 exact test")
plt.xlabel("Taskset Cardinality")  # 横坐标名字
plt.ylabel("States")  # 纵坐标名字
# plt.yscale("log")
plt.legend(loc="best")  # 图例
plt.savefig("states.svg", format="svg")
plt.show()
